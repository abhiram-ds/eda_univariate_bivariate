# %% [markdown]
# # <font color=blue>Start of Case Study: EDA</font>

# %%
##Import the python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
##Load the Application CSV data file provided for Current Loan Application into Dataframe
appl_df=pd.read_csv("application_data.csv")

# %%
#Check the data in the Dataframe
appl_df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
#Check the info about the dataframe
appl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 122 entries, SK_ID_CURR to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(41), object(16)
# memory usage: 286.2+ MB

# %%
#Describe the column values in the Dataframe
appl_df.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %% [markdown]
# ## <font color=blue>Data Cleaning for Application Dataframe</font>

# %%
# Check the column wise null percentages. Fetch all columns with 50% or more null values

appl_null_fields=((appl_df.isnull().sum())/len(appl_df.index) * 100)
print(appl_null_fields[appl_null_fields >= 50])
# Out:
# OWN_CAR_AGE                 65.990810
# EXT_SOURCE_1                56.381073
# APARTMENTS_AVG              50.749729
# BASEMENTAREA_AVG            58.515956
# YEARS_BUILD_AVG             66.497784
# COMMONAREA_AVG              69.872297
# ELEVATORS_AVG               53.295980
# ENTRANCES_AVG               50.348768
# FLOORSMIN_AVG               67.848630
# LANDAREA_AVG                59.376738
# LIVINGAPARTMENTS_AVG        68.354953
# LIVINGAREA_AVG              50.193326
# NONLIVINGAPARTMENTS_AVG     69.432963
# NONLIVINGAREA_AVG           55.179164
# APARTMENTS_MODE             50.749729
# BASEMENTAREA_MODE           58.515956
# YEARS_BUILD_MODE            66.497784
# COMMONAREA_MODE             69.872297
# ELEVATORS_MODE              53.295980
# ENTRANCES_MODE              50.348768
# FLOORSMIN_MODE              67.848630
# LANDAREA_MODE               59.376738
# LIVINGAPARTMENTS_MODE       68.354953
# LIVINGAREA_MODE             50.193326
# NONLIVINGAPARTMENTS_MODE    69.432963
# ...

# %%
#Drop the columns with 50% or higher NULL values
appl_df.dropna(axis=1,thresh=len(appl_df.index)/2,inplace=True)

# %%
#Check the shape of the Dataframe after dropping the high NULL columns
appl_df.shape
# Out:
# (307511, 81)

# %%
#Check the remaining fields which have NULLs

appl_null_fields=((appl_df.isnull().sum())/len(appl_df.index) * 100)
appl_null_fields[appl_null_fields > 0].sort_values(ascending=False)
# Out:
# FLOORSMAX_MEDI                  49.760822
# FLOORSMAX_AVG                   49.760822
# FLOORSMAX_MODE                  49.760822
# YEARS_BEGINEXPLUATATION_AVG     48.781019
# YEARS_BEGINEXPLUATATION_MODE    48.781019
# YEARS_BEGINEXPLUATATION_MEDI    48.781019
# TOTALAREA_MODE                  48.268517
# EMERGENCYSTATE_MODE             47.398304
# OCCUPATION_TYPE                 31.345545
# EXT_SOURCE_3                    19.825307
# AMT_REQ_CREDIT_BUREAU_QRT       13.501631
# AMT_REQ_CREDIT_BUREAU_YEAR      13.501631
# AMT_REQ_CREDIT_BUREAU_HOUR      13.501631
# AMT_REQ_CREDIT_BUREAU_DAY       13.501631
# AMT_REQ_CREDIT_BUREAU_WEEK      13.501631
# AMT_REQ_CREDIT_BUREAU_MON       13.501631
# NAME_TYPE_SUITE                  0.420148
# OBS_30_CNT_SOCIAL_CIRCLE         0.332021
# DEF_30_CNT_SOCIAL_CIRCLE         0.332021
# OBS_60_CNT_SOCIAL_CIRCLE         0.332021
# DEF_60_CNT_SOCIAL_CIRCLE         0.332021
# EXT_SOURCE_2                     0.214626
# ...

# %% [markdown]
# ### <font color=blue>All the columns which are missing values are due to information not supplied during the application or not being a mandatory field. Trying to cast/impute values of these data values can mislead to invalid analysis. So not imputing these values. The imputing can be done as necessiated or if the column is required for further analysis.</font>

# %% [markdown]
# ### <font color=blue>Start the Univariate analysis and find Data imbalances if any</font>

# %%
#Check the values in the TARGET column, which indicates the possibility of Default
appl_df['TARGET'].value_counts()
# Out:
# 0    282686
# 1     24825
# Name: TARGET, dtype: int64

# %%
#Find the percentage of values in TARGET column
appl_df['TARGET'].value_counts()/len(appl_df.index) * 100
# Out:
# 0    91.927118
# 1     8.072882
# Name: TARGET, dtype: float64

# %%
# Plot a pie chart to visualise the percentage of '0' (No missed payments) and '1'(Missed Payments)
pie_labels = ['TARGET=0', 'TARGET=1']
pie_sizes = appl_df['TARGET'].value_counts()/len(appl_df.index) * 100
explode = (0.1, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots(figsize = (5,6))
ax1.pie(pie_sizes, labels=pie_labels, explode = explode, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  # Set aspect ratio to ensure that pie will be a circle.
plt.title('SPLIT OF APPLICATION COUNT BASED ON TARGET VALUES')
plt.show()

# %% [markdown]
# #### Plot a pie chart to visualise the percentage of DEFAULTS by gender wise

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10,6))
pie_labels = ['TARGET=0', 'TARGET=1']
explode = (0.1, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

pie_sizes_f = appl_df.loc[appl_df['CODE_GENDER'] == 'F']['TARGET'].value_counts()/len(appl_df.index) * 100
ax1.pie(pie_sizes_f, labels=pie_labels, explode = explode, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  # Set aspect ratio to ensure that pie will be a circle.
ax1.set_title('FEMALE APPLICANTS')


pie_sizes_m = appl_df.loc[appl_df['CODE_GENDER'] == 'M']['TARGET'].value_counts()/len(appl_df.index) * 100
ax2.pie(pie_sizes_m, labels=pie_labels, explode = explode, autopct='%1.1f%%',shadow=True, startangle=90)
ax2.axis('equal')  # Set aspect ratio to ensure that pie will be a circle.
ax2.set_title('MALE APPLICANTS')

plt.show()

# %% [markdown]
# #### <font color=blue>Using above graph we can understand that MALE applicants are 3% MORE likely to default than FEMALE applicants</font>

# %% [markdown]
# ### <font color=blue> Find the imbalance in the Data based on GENDER counts </font>

# %%
#Print the total count of values as well as percentages
print(appl_df['CODE_GENDER'].value_counts())
appl_df['CODE_GENDER'].value_counts()/len(appl_df.index) * 100
# Out:
# F      202448
# M      105059
# XNA         4
# Name: CODE_GENDER, dtype: int64
# F      65.834393
# M      34.164306
# XNA     0.001301
# Name: CODE_GENDER, dtype: float64

# %% [markdown]
# ##### <font color=blue> Data Imbalance observed in the data.
# From the data given, the number of FEMALE applicants at 66% is double that of MALE applicants.
# Because of which, the GENDER based analysis might be skewed as we dont have enough samples of MALE applicants
# Possible solution is to Under sample the FEMALE applicant entries by reducing it to around same count as MALE applicants (1033388) </font>

# %% [markdown]
# ### <font color=blue> Start the analysis of Continuos variables (NUMBER fields) </font>

# %%
appl_df[['AMT_INCOME_TOTAL','AMT_CREDIT','AMT_ANNUITY','AMT_GOODS_PRICE']].describe()
# Out:
#        AMT_INCOME_TOTAL    AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE
# count      3.075110e+05  3.075110e+05  307499.000000     3.072330e+05
# mean       1.687979e+05  5.990260e+05   27108.573909     5.383962e+05
# std        2.371231e+05  4.024908e+05   14493.737315     3.694465e+05
# min        2.565000e+04  4.500000e+04    1615.500000     4.050000e+04
# 25%        1.125000e+05  2.700000e+05   16524.000000     2.385000e+05
# 50%        1.471500e+05  5.135310e+05   24903.000000     4.500000e+05
# 75%        2.025000e+05  8.086500e+05   34596.000000     6.795000e+05
# max        1.170000e+08  4.050000e+06  258025.500000     4.050000e+06

# %%
#CREATE DERIVED COLUMNS FROM THE AMOUNT VARIABLES 
appl_df['CREDIT_TO_INCOME_RATIO'] = round(appl_df['AMT_CREDIT']/appl_df['AMT_INCOME_TOTAL'],2)
appl_df['ANNUITY_TO_INCOME_RATIO'] = round(appl_df['AMT_ANNUITY']/appl_df['AMT_INCOME_TOTAL'],2)

# %%
appl_df[['CREDIT_TO_INCOME_RATIO','ANNUITY_TO_INCOME_RATIO']].describe()
# Out:
#        CREDIT_TO_INCOME_RATIO  ANNUITY_TO_INCOME_RATIO
# count           307511.000000            307499.000000
# mean                 3.957585                 0.180948
# std                  2.689684                 0.094595
# min                  0.000000                 0.000000
# 25%                  2.020000                 0.110000
# 50%                  3.270000                 0.160000
# 75%                  5.160000                 0.230000
# max                 84.740000                 1.880000

# %%
#CHECK THE COLUMNS WITH DAYS VALUES
appl_df[['DAYS_BIRTH','DAYS_EMPLOYED','DAYS_REGISTRATION','DAYS_ID_PUBLISH']].describe()
# Out:
#           DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH
# count  307511.000000  307511.000000      307511.000000    307511.000000
# mean   -16036.995067   63815.045904       -4986.120328     -2994.202373
# std      4363.988632  141275.766519        3522.886321      1509.450419
# min    -25229.000000  -17912.000000      -24672.000000     -7197.000000
# 25%    -19682.000000   -2760.000000       -7479.500000     -4299.000000
# 50%    -15750.000000   -1213.000000       -4504.000000     -3254.000000
# 75%    -12413.000000    -289.000000       -2010.000000     -1720.000000
# max     -7489.000000  365243.000000           0.000000         0.000000

# %%
#For DAYS, entire data is given with negative sign, probably the calculation was done with ACTUAL DATE - Application Date
#So convert the value to positive and compute the age in terms of years

appl_df['AGE_IN_YEARS'] = round(abs(appl_df['DAYS_BIRTH'])/(365),2)
appl_df['DAYS_BIRTH'] = abs(appl_df['DAYS_BIRTH'])
appl_df['DAYS_EMPLOYED'] = abs(appl_df['DAYS_EMPLOYED'])
appl_df['DAYS_REGISTRATION'] = abs(appl_df['DAYS_REGISTRATION'])
appl_df['DAYS_ID_PUBLISH'] = abs(appl_df['DAYS_ID_PUBLISH'])
appl_df['DAYS_LAST_PHONE_CHANGE'] = abs(appl_df['DAYS_LAST_PHONE_CHANGE'])

# %%
# Check the Fields after update
appl_df[['AGE_IN_YEARS','DAYS_BIRTH','DAYS_EMPLOYED','DAYS_REGISTRATION','DAYS_ID_PUBLISH','DAYS_LAST_PHONE_CHANGE']].describe()
# Out:
#         AGE_IN_YEARS     DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# count  307511.000000  307511.000000  307511.000000      307511.000000
# mean       43.936976   16036.995067   67724.742149        4986.120328
# std        11.956135    4363.988632  139443.751806        3522.886321
# min        20.520000    7489.000000       0.000000           0.000000
# 25%        34.010000   12413.000000     933.000000        2010.000000
# 50%        43.150000   15750.000000    2219.000000        4504.000000
# 75%        53.920000   19682.000000    5707.000000        7479.500000
# max        69.120000   25229.000000  365243.000000       24672.000000
#
#        DAYS_ID_PUBLISH  DAYS_LAST_PHONE_CHANGE
# count    307511.000000           307510.000000
# mean       2994.202373              962.858788
# std        1509.450419              826.808487
# min           0.000000                0.000000
# 25%        1720.000000              274.000000
# 50%        3254.000000              757.000000
# ...

# %% [markdown]
# #### <font color=blue> Impute the high OUTLIER value in DAYS_EMPLOYED column </font>

# %%
##CHECK THE COUNT OF APPLICATIONS BASED ON TARGET VALUE WITH HIGH OUTLIER  VALUE OF DAYS_EMPLOYED
appl_df.loc[appl_df['DAYS_EMPLOYED'] == 365243]['TARGET'].value_counts()/len(appl_df.loc[appl_df['DAYS_EMPLOYED'] == 365243].index) * 100
# Out:
# 0    94.600354
# 1     5.399646
# Name: TARGET, dtype: float64

# %% [markdown]
# #### <font color=blue> Analysisng the data, we see that the abnormal outlier value doesn't really mean that the data is corrupted. Only this 1 columns needs to be imputed </font>

# %%
appl_df['DAYS_EMPLOYED'].replace({365243: np.nan}, inplace=True)

# %% [markdown]
# #### <font color=blue> Check the data after imputing </font>

# %%
appl_df[['AGE_IN_YEARS','DAYS_BIRTH','DAYS_EMPLOYED','DAYS_REGISTRATION','DAYS_ID_PUBLISH']].describe()
# Out:
#         AGE_IN_YEARS     DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# count  307511.000000  307511.000000  252137.000000      307511.000000
# mean       43.936976   16036.995067    2384.169325        4986.120328
# std        11.956135    4363.988632    2338.360162        3522.886321
# min        20.520000    7489.000000       0.000000           0.000000
# 25%        34.010000   12413.000000     767.000000        2010.000000
# 50%        43.150000   15750.000000    1648.000000        4504.000000
# 75%        53.920000   19682.000000    3175.000000        7479.500000
# max        69.120000   25229.000000   17912.000000       24672.000000
#
#        DAYS_ID_PUBLISH
# count    307511.000000
# mean       2994.202373
# std        1509.450419
# min           0.000000
# 25%        1720.000000
# 50%        3254.000000
# 75%        4299.000000
# max        7197.000000

# %%
appl_df.shape
# Out:
# (307511, 84)

# %% [markdown]
# #### <font color = blue> CREATE A DERIVED NUMERICAL COLUMN GENDER_INDICATOR OUT OF CATEGORICAL VARIABLE CODE_GENDER </font>

# %%
print(appl_df.groupby('CODE_GENDER').SK_ID_CURR.count())
appl_df['GENDER_INDICATOR']=np.nan

#MARK FEMALE AS 1 AND MALE AS O; IGNORING THE VALUE WITH CODE_GENDER 'XNA' TREATING IT AS SPECIAL CASE (ONLY 4 RECORDS)
appl_df.loc[appl_df['CODE_GENDER'] == 'F','GENDER_INDICATOR']=1
appl_df.loc[appl_df['CODE_GENDER'] == 'M','GENDER_INDICATOR']=0

appl_df['GENDER_INDICATOR'].value_counts()
# Out:
# CODE_GENDER
# F      202448
# M      105059
# XNA         4
# Name: SK_ID_CURR, dtype: int64
# 1.0    202448
# 0.0    105059
# Name: GENDER_INDICATOR, dtype: int64

# %%
#There are 4 records with XNA as CODE_GENDER. This data is very minor and can be ignored
appl_df.loc[appl_df['CODE_GENDER']=='XNA']
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 35657       141289       0    Revolving loans         XNA            Y
# 38566       144669       0    Revolving loans         XNA            N
# 83382       196708       0    Revolving loans         XNA            N
# 189640      319880       0    Revolving loans         XNA            Y
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 35657                Y             0          207000.0    382500.0
# 38566                Y             2          157500.0    270000.0
# 83382                Y             1          135000.0    405000.0
# 189640               Y             0          247500.0    540000.0
#
#         AMT_ANNUITY        ...         AMT_REQ_CREDIT_BUREAU_HOUR  \
# 35657       19125.0        ...                                0.0
# 38566       13500.0        ...                                0.0
# 83382       20250.0        ...                                0.0
# ...

# %% [markdown]
# ## <font color=blue> START THE ANALYSIS TO FIND CORRELATION BETWEEN VARIABLES WITH THE TARGET COLUMNS </font>

# %%
#Need to find correlation  with Target to draw univariate, bivariate and segmented univariate
corr_df = appl_df.corr()['TARGET'].sort_values()
print('Positive Correlations: ', corr_df.tail(10))
print('Negative Correlations: ', corr_df.head(10))
# Out:
# Positive Correlations:  DEF_60_CNT_SOCIAL_CIRCLE       0.031276
# DEF_30_CNT_SOCIAL_CIRCLE       0.032248
# LIVE_CITY_NOT_WORK_CITY        0.032518
# FLAG_DOCUMENT_3                0.044346
# REG_CITY_NOT_LIVE_CITY         0.044395
# FLAG_EMP_PHONE                 0.045982
# REG_CITY_NOT_WORK_CITY         0.050994
# REGION_RATING_CLIENT           0.058899
# REGION_RATING_CLIENT_W_CITY    0.060893
# TARGET                         1.000000
# Name: TARGET, dtype: float64
# Negative Correlations:  EXT_SOURCE_3             -0.178919
# EXT_SOURCE_2             -0.160472
# AGE_IN_YEARS             -0.078239
# DAYS_BIRTH               -0.078239
# DAYS_EMPLOYED            -0.074958
# DAYS_LAST_PHONE_CHANGE   -0.055218
# GENDER_INDICATOR         -0.054710
# DAYS_ID_PUBLISH          -0.051457
# FLOORSMAX_AVG            -0.044003
# FLOORSMAX_MEDI           -0.043768
# Name: TARGET, dtype: float64

# %% [markdown]
# ### <font color=blue> The correlation is on both sides i.e. few variables affecting the loan default (TARGET=1) behavior positively as well as some variables impacting negative. Negative impact implies less loan default chance and hence indicator of credit worthy applicant. We will be considering the top variables on either sides with > 0.05 (absolute) correlation. </font>

# %%
print('Driver Variables Correlations: ', corr_df[abs(corr_df.values) >= 0.05])
# Out:
# Driver Variables Correlations:  EXT_SOURCE_3                  -0.178919
# EXT_SOURCE_2                  -0.160472
# AGE_IN_YEARS                  -0.078239
# DAYS_BIRTH                    -0.078239
# DAYS_EMPLOYED                 -0.074958
# DAYS_LAST_PHONE_CHANGE        -0.055218
# GENDER_INDICATOR              -0.054710
# DAYS_ID_PUBLISH               -0.051457
# REG_CITY_NOT_WORK_CITY         0.050994
# REGION_RATING_CLIENT           0.058899
# REGION_RATING_CLIENT_W_CITY    0.060893
# TARGET                         1.000000
# Name: TARGET, dtype: float64

# %%
##GET THE DATA DESCRIPTION OF ALL THE CORRELATED COLUMNS
appl_df[['EXT_SOURCE_3','EXT_SOURCE_2','AGE_IN_YEARS','DAYS_BIRTH','DAYS_EMPLOYED','DAYS_LAST_PHONE_CHANGE','GENDER_INDICATOR','DAYS_ID_PUBLISH','REG_CITY_NOT_WORK_CITY','REGION_RATING_CLIENT','REGION_RATING_CLIENT_W_CITY']].describe()
# Out:
#         EXT_SOURCE_3  EXT_SOURCE_2   AGE_IN_YEARS     DAYS_BIRTH  \
# count  246546.000000  3.068510e+05  307511.000000  307511.000000
# mean        0.510853  5.143927e-01      43.936976   16036.995067
# std         0.194844  1.910602e-01      11.956135    4363.988632
# min         0.000527  8.173617e-08      20.520000    7489.000000
# 25%         0.370650  3.924574e-01      34.010000   12413.000000
# 50%         0.535276  5.659614e-01      43.150000   15750.000000
# 75%         0.669057  6.636171e-01      53.920000   19682.000000
# max         0.896010  8.549997e-01      69.120000   25229.000000
#
#        DAYS_EMPLOYED  DAYS_LAST_PHONE_CHANGE  GENDER_INDICATOR  \
# count  252137.000000           307510.000000     307507.000000
# mean     2384.169325              962.858788          0.658352
# std      2338.360162              826.808487          0.474263
# min         0.000000                0.000000          0.000000
# ...

# %% [markdown]
# ### <font color = blue> Here, of all numerical vakues, AGE_IN_YEARS is closer to TARGET which is 0.078239. Hence we Will consider this for univariate, bivariate and segmented univariate with Target
# <font color = blue>Age Univariate graph </font>

# %%
plt.figure(figsize = (10, 5))
plt.hist(appl_df['AGE_IN_YEARS'] , edgecolor = 'k', bins = 25)
plt.title('AGE UNIVARIATE ANALYSIS')
plt.xlabel('AGE (IN YEARS)')
plt.ylabel('APPLICATION COUNT')
plt.show()

# %% [markdown]
#  ### <font color = blue> To further understand the data distribution across age, we will do a Kernel density estimate / Segmented Univariate analysis. </font>

# %%
plt.figure(figsize = (8, 5))
sns.kdeplot(appl_df.loc[appl_df['TARGET'] == 0, 'AGE_IN_YEARS'] , label='Target = 0')
sns.kdeplot(appl_df.loc[appl_df['TARGET'] == 1, 'AGE_IN_YEARS'] , label='Target = 1')
plt.title('AGE_IN_YEARS SEGMENTED UNIVARIATE');
plt.xlabel('AGE_IN_YEARS WITH TARGET')
plt.show()

# %% [markdown]
# ### <font color=blue> From the above PLOT,we can understand that the high default TARGET=1 is around the age group of 27-32. While safe customers are those with Age > 32 </font>

# %% [markdown]
# ### <font color = blue> Let us further analyse this with BI-VARIATE CATEGORICAL DATA </font>

# %%
plt.figure(figsize = (10, 5))
sns.kdeplot(appl_df.loc[(appl_df['CODE_GENDER'] == 'F') & (appl_df['TARGET'] == 0), 'AGE_IN_YEARS'] , label='FEMALE-0')
sns.kdeplot(appl_df.loc[(appl_df['CODE_GENDER'] == 'F') & (appl_df['TARGET'] == 1), 'AGE_IN_YEARS'] , label='FEMALE-1')
sns.kdeplot(appl_df.loc[(appl_df['CODE_GENDER'] == 'M') & (appl_df['TARGET'] == 0), 'AGE_IN_YEARS'] , label='MALE-0')
sns.kdeplot(appl_df.loc[(appl_df['CODE_GENDER'] == 'M') & (appl_df['TARGET'] == 1), 'AGE_IN_YEARS'] , label='MALE-1')
plt.title('AGE_IN_YEARS & GENDER BI-VARIATE CATEGORICAL');
plt.xlabel('AGE_IN_YEARS & GENDER WITH TARGET')
plt.show()

# %% [markdown]
# ### <font color=blue> From the above BI-VARIATE CATEGORICAL kde plot,we can infer that MALE & FEMALE APPLICANTS within the age group of 27-32 are high risk, where as  that the reliable customer age group starts around 33 for MALE applicats and around 35 for FEMALE applicants.</font>

# %% [markdown]
# ### <font color = blue> Create a Correlation Plot to visualise the impact of Driver Variables </font>

# %%
#Create a correlation Matrix for the Per Capita GSDP against the school dropt out rate 
target_to_driver_corr=appl_df[['TARGET','EXT_SOURCE_3','EXT_SOURCE_2','AGE_IN_YEARS','DAYS_EMPLOYED','DAYS_LAST_PHONE_CHANGE','GENDER_INDICATOR','DAYS_ID_PUBLISH','REG_CITY_NOT_WORK_CITY','REGION_RATING_CLIENT','REGION_RATING_CLIENT_W_CITY']].corr()

#Generate a heapmap to visualise the correlation betwwen the values
cmap = sns.cm.rocket_r
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(target_to_driver_corr,annot=True,cmap = cmap)
plt.title('TOP CORRELATION DRIVER VARIABLES FOR TARGET COLUMN')
# Out:
# Text(0.5, 1.0, 'TOP CORRELATION DRIVER VARIABLES FOR TARGET COLUMN')

# %% [markdown]
# ## <font color=blue>Import the Previous application data set </font>

# %%
prev_appl_df = pd.read_csv("previous_application.csv")
print("Previous applications has {0} rows and {1} columns".format(prev_appl_df.shape[0], prev_appl_df.shape[1]))
# Out:
# Previous applications has 1670214 rows and 37 columns

# %%
prev_appl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
# SK_ID_PREV                     1670214 non-null int64
# SK_ID_CURR                     1670214 non-null int64
# NAME_CONTRACT_TYPE             1670214 non-null object
# AMT_ANNUITY                    1297979 non-null float64
# AMT_APPLICATION                1670214 non-null float64
# AMT_CREDIT                     1670213 non-null float64
# AMT_DOWN_PAYMENT               774370 non-null float64
# AMT_GOODS_PRICE                1284699 non-null float64
# WEEKDAY_APPR_PROCESS_START     1670214 non-null object
# HOUR_APPR_PROCESS_START        1670214 non-null int64
# FLAG_LAST_APPL_PER_CONTRACT    1670214 non-null object
# NFLAG_LAST_APPL_IN_DAY         1670214 non-null int64
# RATE_DOWN_PAYMENT              774370 non-null float64
# RATE_INTEREST_PRIMARY          5951 non-null float64
# RATE_INTEREST_PRIVILEGED       5951 non-null float64
# ...

# %%
prev_appl_df.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# ...

# %% [markdown]
# ### <font color=blue>Remove the high NULL % columns</font>

# %%
# Check the column wise null percentages. Fetch all columns with 50% or more null values
prev_appl_null_fields=((prev_appl_df.isnull().sum())/len(prev_appl_df.index) * 100)
print(prev_appl_null_fields[prev_appl_null_fields >= 50])
# Out:
# AMT_DOWN_PAYMENT            53.636480
# RATE_DOWN_PAYMENT           53.636480
# RATE_INTEREST_PRIMARY       99.643698
# RATE_INTEREST_PRIVILEGED    99.643698
# dtype: float64

# %%
#Drop the columns with 50% or higher NULL values
prev_appl_df.dropna(axis=1,thresh=len(prev_appl_df.index)/2,inplace=True)

# %%
##CHECK THE SHAPE OF PREVIOUS APPLICATION DATA SET
prev_appl_df.shape
# Out:
# (1670214, 33)

# %%
##CHECK THE SHAPE OF CURRENT APPLICATION DATA SET
appl_df.shape
# Out:
# (307511, 85)

# %% [markdown]
# ### <font color=blue> Merge the Current and Previous application Data Sets </font>

# %%
##MERGE THE PREVIOUS APPLICATION DATA INTO THE CURRENT APPLICATION DATAFRAME
merged_appl_df = appl_df.merge(prev_appl_df, on='SK_ID_CURR', how='left')
print("Merged applications has {0} rows and {1} columns".format(merged_appl_df.shape[0], merged_appl_df.shape[1]))
# Out:
# Merged applications has 1430155 rows and 117 columns

# %%
##CHECK THE STATUS OF APPLICATIONS IN MERGED DATA SET
merged_appl_df['NAME_CONTRACT_STATUS'].value_counts()
# Out:
# Approved        886099
# Canceled        259441
# Refused         245390
# Unused offer     22771
# Name: NAME_CONTRACT_STATUS, dtype: int64

# %%
##CHECK THE APPROVED APPLICATION DATA
merged_appl_df.loc[merged_appl_df['NAME_CONTRACT_STATUS']=='Approved'].head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1           Cash loans           M            N
# 1      100003       0           Cash loans           F            N
# 2      100003       0           Cash loans           F            N
# 3      100003       0           Cash loans           F            N
# 4      100004       0      Revolving loans           M            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  \
# 0               Y             0          202500.0      406597.5
# 1               N             0          270000.0     1293502.5
# 2               N             0          270000.0     1293502.5
# 3               N             0          270000.0     1293502.5
# 4               Y             0           67500.0      135000.0
#
#    AMT_ANNUITY_x            ...              NAME_SELLER_INDUSTRY CNT_PAYMENT  \
# 0        24700.5            ...                   Auto technology        24.0
# ...

# %%
##PLOT THE EMPLOYMENT EXPERIENCE PLOT BASED ON THE APPROVED STATUS OF APPLICATION FOR MERGED DATA
merged_appl_emp = merged_appl_df.loc[merged_appl_df['NAME_CONTRACT_STATUS']=='Approved'][['DAYS_EMPLOYED','TARGET']]
merged_appl_emp['EMP_YEARS'] = merged_appl_emp['DAYS_EMPLOYED'] / 365
merged_appl_emp['EMP_YEARS_BINS'] = pd.cut(merged_appl_emp['EMP_YEARS'], bins = np.linspace( 0.00, 50.00, num = 20))
merged_appl_emp_ctgy  = merged_appl_emp.groupby('EMP_YEARS_BINS').mean()
print(merged_appl_emp_ctgy)
# Out:
#                   DAYS_EMPLOYED    TARGET  EMP_YEARS
# EMP_YEARS_BINS
# (0.0, 2.632]         511.097184  0.105640   1.400266
# (2.632, 5.263]      1413.403270  0.090899   3.872338
# (5.263, 7.895]      2386.925603  0.073629   6.539522
# (7.895, 10.526]     3311.357341  0.065317   9.072212
# (10.526, 13.158]    4292.197542  0.054652  11.759445
# (13.158, 15.789]    5243.315784  0.055050  14.365249
# (15.789, 18.421]    6221.486145  0.056179  17.045168
# (18.421, 21.053]    7182.783454  0.047577  19.678859
# (21.053, 23.684]    8122.622811  0.049496  22.253761
# (23.684, 26.316]    9105.921053  0.049043  24.947729
# (26.316, 28.947]   10071.451660  0.039212  27.593018
# (28.947, 31.579]   11016.052434  0.046549  30.180966
# (31.579, 34.211]   11994.108148  0.038148  32.860570
# (34.211, 36.842]   12885.475987  0.030950  35.302674
# (36.842, 39.474]   13908.251838  0.018382  38.104800
# (39.474, 42.105]   14806.260377  0.013208  40.565097
# ...

# %%
##PLOT THE HISOGRAM WITH EMP EXPERIENCE BINS AND ANALYSE THE COUNR OF APPROVED APPLICATIONS FROM MERGED DATA
plt.figure(figsize = (16, 6))
plt.bar(merged_appl_emp_ctgy.index.astype(str), 100 * merged_appl_emp_ctgy['TARGET'])

plt.xticks(rotation=90)
plt.xlabel('MERGED DATA - EMP EXPERIENCE FOR APPROVED APPLICATIONS WITH TARGET 1 (DEFAULT)')
plt.ylabel('DEFAULT %')
plt.title('MERGED DATA -EMPLOYMENT EXPERIENCE FOR APPROVED APPLICATIONS BI-VARIATE WITH TARGET DEFAULT')
plt.show()

# %%
##PLOT THE EMPLOYMENT EXPERIENCE PLOT FOR CURRENT APPLICATION DATA
appl_emp = appl_df[['TARGET', 'DAYS_EMPLOYED']]
appl_emp['EMP_YEARS'] = appl_emp['DAYS_EMPLOYED'] / 365
appl_emp['EMP_YEARS_BINS'] = pd.cut(appl_emp['EMP_YEARS'], bins = np.linspace( 0.00, 50.00, num = 20))
appl_emp_ctgy  = appl_emp.groupby('EMP_YEARS_BINS').mean()
print(appl_emp_ctgy)
# Out:
#                     TARGET  DAYS_EMPLOYED  EMP_YEARS
# EMP_YEARS_BINS
# (0.0, 2.632]      0.111791     501.314145   1.373463
# (2.632, 5.263]    0.096504    1405.092567   3.849569
# (5.263, 7.895]    0.075852    2379.404101   6.518915
# (7.895, 10.526]   0.066731    3314.993737   9.082175
# (10.526, 13.158]  0.056588    4292.383226  11.759954
# (13.158, 15.789]  0.054335    5244.548797  14.368627
# (15.789, 18.421]  0.051187    6222.491821  17.047923
# (18.421, 21.053]  0.043205    7186.020408  19.687727
# (21.053, 23.684]  0.047860    8122.745838  22.254098
# (23.684, 26.316]  0.049404    9102.980150  24.939672
# (26.316, 28.947]  0.035012   10076.294840  27.606287
# (28.947, 31.579]  0.046142   11007.660363  30.157974
# (31.579, 34.211]  0.041096   11988.654373  32.845628
# (34.211, 36.842]  0.026012   12893.658960  35.325093
# (36.842, 39.474]  0.016901   13898.969014  38.079367
# (39.474, 42.105]  0.011236   14817.780899  40.596660
# ...

# %%
##PLOT THE HISOGRAM WITH EMP EXPERIENCE BINS AND ANALYSE THE COUNT FROM ALL CURRENT DATA
plt.figure(figsize = (16, 6))
plt.bar(appl_emp_ctgy.index.astype(str), 100 * appl_emp_ctgy['TARGET'])

plt.xticks(rotation=90)
plt.xlabel('EMPLOYMENT EXPERIENCE WITH TARGET 1 (DEFAULT)')
plt.ylabel('DEFAULT %')
plt.title('EMPLOYMENT EXPERIENCE BI-VARIATE WITH TARGET DEFAULT')
plt.show()

# %% [markdown]
# ## <font color=blue> From the Employment Experience Bi-variate plot for TARGET column, on both the CURRENT APPLICATION DATA & the MERGED DATA (OF APPROVED APPLICATIONS), it is clear that with high years of experience, there is a very less (almost to ZERO) chance of customer doing a DEFAULT on Loan </font>
